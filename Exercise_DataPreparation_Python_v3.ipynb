# %% [markdown]
# # Exercise Data preparation with Python

# %%
import os
import pandas as pd
import numpy as np
os.getcwd()
os.chdir("E:/R_Working_Directory")
os.getcwd()
# Out:
# 'E:\\R_Working_Directory'

# %%
#if we want to know the separator of the csv one way we could do
# is to open the first n rows of the csv file
df1=pd.read_csv("TrainingData_latest.csv",sep=",",nrows=10)
df1
# Out:
#   ID; NumComplains; hour_id; LCID; RACH_Setup_Completion_Success_Rate_AVG; Total_RRC_Connection_Setup_Success_Ratio_AVG; Total_RRC_Connection_Re_establishment_Success_Ratio_AVG; Radio_Bearer_Success_Ratio_AVG; ERAB_SetupSR_AVG; HO_Success_Ratio_intra_eNB_AVG; Average_CQI_AVG; Radio_Bearer_Drop_Ratio_AVG; Average_Physical_Resource_Block_Usage_UL_AVG; Average_Physical_Resource_Block_Usage_DL_AVG; Complete_RACH_Setup_Success_Rate_AVG; AGG1_blocked_distribution_rate_AVG; AGG2_blocked_distribution_rate_AVG; AGG4_blocked_distribution_rate_AVG; AGG8_blocked_distribution_rate_AVG; ECM_failure_ratio_due_to_Rejection_by_RRM_RAC_AVG; AGG_level_block_Rate_AVG; ERAB_Drop_Ratio_with_UE_Lost_cause_initiated_by_eNB_AVG
# 0  1;1;11/20/2015 0:03;33378111;0.992407;0.998720...
# 1  2;1;11/20/2015 0:27;23596112;0.9992299;0.99351...
# 2  3;1;11/20/2015 0:29;10611113;0.9845909;0.99878...
# 3  4;1;11/20/2015 2:11;50982112;0.994961;0.998095...
# 4  5;1;11/20/2015 2:12;24738113;0.9854881;0.99867...
# ...

# %%
df=pd.read_csv("TrainingData_latest.csv",sep=";")
df.shape
# Out:
# (13949, 22)

# %%
df.head()
# Out:
#    ID   NumComplains          hour_id      LCID  \
# 0   1              1  11/20/2015 0:03  33378111
# 1   2              1  11/20/2015 0:27  23596112
# 2   3              1  11/20/2015 0:29  10611113
# 3   4              1  11/20/2015 2:11  50982112
# 4   5              1  11/20/2015 2:12  24738113
#
#     RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                 0.992407
# 1                                 0.999230
# 2                                 0.984591
# 3                                 0.994961
# 4                                 0.985488
#
#     Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                       0.998720
# 1                                       0.993518
# 2                                       0.998783
# 3                                       0.998095
# 4                                       0.998673
#
#     Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13949 entries, 0 to 13948
# Data columns (total 22 columns):
# ID                                                          13949 non-null int64
#  NumComplains                                               13949 non-null int64
#  hour_id                                                    13949 non-null object
#  LCID                                                       13949 non-null object
#  RACH_Setup_Completion_Success_Rate_AVG                     13948 non-null float64
#  Total_RRC_Connection_Setup_Success_Ratio_AVG               13947 non-null float64
#  Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    13538 non-null float64
#  Radio_Bearer_Success_Ratio_AVG                             13947 non-null float64
#  ERAB_SetupSR_AVG                                           13947 non-null float64
#  HO_Success_Ratio_intra_eNB_AVG                             13799 non-null float64
# ...

# %%
Colname_df=list(df.columns)
Colname_df
# Out:
# ['ID',
#  ' NumComplains',
#  ' hour_id',
#  ' LCID',
#  ' RACH_Setup_Completion_Success_Rate_AVG',
#  ' Total_RRC_Connection_Setup_Success_Ratio_AVG',
#  ' Total_RRC_Connection_Re_establishment_Success_Ratio_AVG',
#  ' Radio_Bearer_Success_Ratio_AVG',
#  ' ERAB_SetupSR_AVG',
#  ' HO_Success_Ratio_intra_eNB_AVG',
#  ' Average_CQI_AVG',
#  ' Radio_Bearer_Drop_Ratio_AVG',
#  ' Average_Physical_Resource_Block_Usage_UL_AVG',
#  ' Average_Physical_Resource_Block_Usage_DL_AVG',
#  ' Complete_RACH_Setup_Success_Rate_AVG',
#  ' AGG1_blocked_distribution_rate_AVG',
#  ' AGG2_blocked_distribution_rate_AVG',
#  ' AGG4_blocked_distribution_rate_AVG',
#  ' AGG8_blocked_distribution_rate_AVG',
#  ' ECM_failure_ratio_due_to_Rejection_by_RRM_RAC_AVG',
#  ' AGG_level_block_Rate_AVG',
#  ' ERAB_Drop_Ratio_with_UE_Lost_cause_initiated_by_eNB_AVG']

# %%
df.columns=[i.replace(" ","") for i in Colname_df]
df.head()
# Out:
#    ID  NumComplains          hour_id      LCID  \
# 0   1             1  11/20/2015 0:03  33378111
# 1   2             1  11/20/2015 0:27  23596112
# 2   3             1  11/20/2015 0:29  10611113
# 3   4             1  11/20/2015 2:11  50982112
# 4   5             1  11/20/2015 2:12  24738113
#
#    RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                0.992407
# 1                                0.999230
# 2                                0.984591
# 3                                0.994961
# 4                                0.985488
#
#    Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                      0.998720
# 1                                      0.993518
# 2                                      0.998783
# 3                                      0.998095
# 4                                      0.998673
#
#    Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# 0                                           0.331485
# ...

# %%
list(df.columns)
# Out:
# ['ID',
#  'NumComplains',
#  'hour_id',
#  'LCID',
#  'RACH_Setup_Completion_Success_Rate_AVG',
#  'Total_RRC_Connection_Setup_Success_Ratio_AVG',
#  'Total_RRC_Connection_Re_establishment_Success_Ratio_AVG',
#  'Radio_Bearer_Success_Ratio_AVG',
#  'ERAB_SetupSR_AVG',
#  'HO_Success_Ratio_intra_eNB_AVG',
#  'Average_CQI_AVG',
#  'Radio_Bearer_Drop_Ratio_AVG',
#  'Average_Physical_Resource_Block_Usage_UL_AVG',
#  'Average_Physical_Resource_Block_Usage_DL_AVG',
#  'Complete_RACH_Setup_Success_Rate_AVG',
#  'AGG1_blocked_distribution_rate_AVG',
#  'AGG2_blocked_distribution_rate_AVG',
#  'AGG4_blocked_distribution_rate_AVG',
#  'AGG8_blocked_distribution_rate_AVG',
#  'ECM_failure_ratio_due_to_Rejection_by_RRM_RAC_AVG',
#  'AGG_level_block_Rate_AVG',
#  'ERAB_Drop_Ratio_with_UE_Lost_cause_initiated_by_eNB_AVG']

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    411
# Radio_Bearer_Drop_Ratio_AVG                                380
# HO_Success_Ratio_intra_eNB_AVG                             150
# Average_Physical_Resource_Block_Usage_UL_AVG                80
# ERAB_SetupSR_AVG                                             2
# Total_RRC_Connection_Setup_Success_Ratio_AVG                 2
# Complete_RACH_Setup_Success_Rate_AVG                         2
# Radio_Bearer_Success_Ratio_AVG                               2
# Average_CQI_AVG                                              1
# RACH_Setup_Completion_Success_Rate_AVG                       1
# NumComplains                                                 0
# hour_id                                                      0
# LCID                                                         0
# ERAB_Drop_Ratio_with_UE_Lost_cause_initiated_by_eNB_AVG      0
# AGG_level_block_Rate_AVG                                     0
# ...

# %%
df.shape[0]-df.dropna(axis=0).shape[0]
# Out:
# 761

# %%
df.shape[0]-df.dropna(thresh=21).shape[0]
# Out:
# 217

# %%
#To remove columns which have more than 10% of missing value
df1=df.dropna(axis=1,thresh=round(df.shape[0]*0.9))

# %%
df1.head()
# Out:
#    ID  NumComplains          hour_id      LCID  \
# 0   1             1  11/20/2015 0:03  33378111
# 1   2             1  11/20/2015 0:27  23596112
# 2   3             1  11/20/2015 0:29  10611113
# 3   4             1  11/20/2015 2:11  50982112
# 4   5             1  11/20/2015 2:12  24738113
#
#    RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                0.992407
# 1                                0.999230
# 2                                0.984591
# 3                                0.994961
# 4                                0.985488
#
#    Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                      0.998720
# 1                                      0.993518
# 2                                      0.998783
# 3                                      0.998095
# 4                                      0.998673
#
#    Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# 0                                           0.331485
# ...

# %%
print("The number of distinct LCID is", len(df["LCID"].unique()))
# Out:
# The number of distinct LCID is 11745

# %%
df["hour_id"]=pd.to_datetime(df["hour_id"],format="%m/%d/%Y %H:%M")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13949 entries, 0 to 13948
# Data columns (total 22 columns):
# ID                                                         13949 non-null int64
# NumComplains                                               13949 non-null int64
# hour_id                                                    13949 non-null datetime64[ns]
# LCID                                                       13949 non-null object
# RACH_Setup_Completion_Success_Rate_AVG                     13948 non-null float64
# Total_RRC_Connection_Setup_Success_Ratio_AVG               13947 non-null float64
# Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    13538 non-null float64
# Radio_Bearer_Success_Ratio_AVG                             13947 non-null float64
# ERAB_SetupSR_AVG                                           13947 non-null float64
# HO_Success_Ratio_intra_eNB_AVG                             13799 non-null float64
# ...

# %%
df.head()
# Out:
#    ID  NumComplains             hour_id      LCID  \
# 0   1             1 2015-11-20 00:03:00  33378111
# 1   2             1 2015-11-20 00:27:00  23596112
# 2   3             1 2015-11-20 00:29:00  10611113
# 3   4             1 2015-11-20 02:11:00  50982112
# 4   5             1 2015-11-20 02:12:00  24738113
#
#    RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                0.992407
# 1                                0.999230
# 2                                0.984591
# 3                                0.994961
# 4                                0.985488
#
#    Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                      0.998720
# 1                                      0.993518
# 2                                      0.998783
# 3                                      0.998095
# 4                                      0.998673
#
#    Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# ...

# %%
#The duration of the data frame
df["hour_id"].max()-df["hour_id"].min()
# Out:
# Timedelta('13 days 15:00:00')

# %%
date1=[i.date() for i in df["hour_id"]]

# %%
df["date1"]=df["hour_id"].dt.date

# %%
df.head()
# Out:
#    ID  NumComplains             hour_id      LCID  \
# 0   1             1 2015-11-20 00:03:00  33378111
# 1   2             1 2015-11-20 00:27:00  23596112
# 2   3             1 2015-11-20 00:29:00  10611113
# 3   4             1 2015-11-20 02:11:00  50982112
# 4   5             1 2015-11-20 02:12:00  24738113
#
#    RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                0.992407
# 1                                0.999230
# 2                                0.984591
# 3                                0.994961
# 4                                0.985488
#
#    Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                      0.998720
# 1                                      0.993518
# 2                                      0.998783
# 3                                      0.998095
# 4                                      0.998673
#
#    Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# ...

# %%
from collections import Counter
Counter(df["date1"])
# Out:
# Counter({datetime.date(2015, 11, 13): 982,
#          datetime.date(2015, 11, 14): 993,
#          datetime.date(2015, 11, 15): 990,
#          datetime.date(2015, 11, 16): 946,
#          datetime.date(2015, 11, 17): 851,
#          datetime.date(2015, 11, 18): 824,
#          datetime.date(2015, 11, 19): 761,
#          datetime.date(2015, 11, 20): 937,
#          datetime.date(2015, 11, 21): 985,
#          datetime.date(2015, 11, 22): 963,
#          datetime.date(2015, 11, 23): 1054,
#          datetime.date(2015, 11, 24): 1095,
#          datetime.date(2015, 11, 25): 1317,
#          datetime.date(2015, 11, 26): 1251})

# %%
#To count the frequecy of different elements in one column of dataframe, 
#We could use Counter() function provided by collections
from collections import Counter
for i,j in Counter(df["date1"]).items():
    print(i,":", j)
# Out:
# 2015-11-20 : 937
# 2015-11-21 : 985
# 2015-11-22 : 963
# 2015-11-23 : 1054
# 2015-11-24 : 1095
# 2015-11-25 : 1317
# 2015-11-26 : 1251
# 2015-11-13 : 982
# 2015-11-14 : 993
# 2015-11-15 : 990
# 2015-11-16 : 946
# 2015-11-17 : 851
# 2015-11-18 : 824
# 2015-11-19 : 761

# %%
#Similary to count the number of occurence of the field NumComplains
Counter(df["NumComplains"])
# Out:
# Counter({0: 12390, 1: 1559})

# %%
df.iloc[:,3:].groupby("LCID").median().head()
# Out:
#           RACH_Setup_Completion_Success_Rate_AVG  \
# LCID
# 10001111                                0.996639
# 10003233                                0.970546
# 10004231                                0.999610
# 10005111                                0.997358
# 10005113                                0.963121
#
#           Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# LCID
# 10001111                                      0.999719
# 10003233                                      0.999731
# 10004231                                      0.999419
# 10005111                                      0.999539
# 10005113                                      0.998851
#
#           Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# LCID
# 10001111                                           0.491298
# 10003233                                           0.220757
# 10004231                                           0.833333
# 10005111                                           0.429804
# ...

# %%
#To count the number of occurence of one column in the data frame
df["LCID"].value_counts().head()
# Out:
# 24880112    28
# 221D7131    10
# 24879131     7
# 80256111     6
# 22156112     6
# Name: LCID, dtype: int64

# %%
df["Region"]=df["LCID"].astype(str).str[:5]

# %%
df.head()
# Out:
#    ID  NumComplains             hour_id      LCID  \
# 0   1             1 2015-11-20 00:03:00  33378111
# 1   2             1 2015-11-20 00:27:00  23596112
# 2   3             1 2015-11-20 00:29:00  10611113
# 3   4             1 2015-11-20 02:11:00  50982112
# 4   5             1 2015-11-20 02:12:00  24738113
#
#    RACH_Setup_Completion_Success_Rate_AVG  \
# 0                                0.992407
# 1                                0.999230
# 2                                0.984591
# 3                                0.994961
# 4                                0.985488
#
#    Total_RRC_Connection_Setup_Success_Ratio_AVG  \
# 0                                      0.998720
# 1                                      0.993518
# 2                                      0.998783
# 3                                      0.998095
# 4                                      0.998673
#
#    Total_RRC_Connection_Re_establishment_Success_Ratio_AVG  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13949 entries, 0 to 13948
# Data columns (total 24 columns):
# ID                                                         13949 non-null int64
# NumComplains                                               13949 non-null int64
# hour_id                                                    13949 non-null datetime64[ns]
# LCID                                                       13949 non-null object
# RACH_Setup_Completion_Success_Rate_AVG                     13948 non-null float64
# Total_RRC_Connection_Setup_Success_Ratio_AVG               13947 non-null float64
# Total_RRC_Connection_Re_establishment_Success_Ratio_AVG    13538 non-null float64
# Radio_Bearer_Success_Ratio_AVG                             13947 non-null float64
# ERAB_SetupSR_AVG                                           13947 non-null float64
# HO_Success_Ratio_intra_eNB_AVG                             13799 non-null float64
# ...
